# %%
from __future__ import print_function, division
import sys
import os
import numpy as np
import pylab as pl
import pandas as pd

#import json
import os
#s = json.load( open(os.getenv('PUI2016')+"/fbb_matplotlibrc.json") )
#pl.rcParams.update(s)

# %pylab inline
# Out:
# Populating the interactive namespace from numpy and matplotlib
# /opt/rh/anaconda/root/envs/PUI2016_Python2/lib/python2.7/site-packages/IPython/core/magics/pylab.py:161: UserWarning: pylab import has clobbered these variables: ['ma', 'isreal']
# `%matplotlib` prevents importing * from pylab and numpy
#   "\n`%matplotlib` prevents importing * from pylab and numpy"

# %%
all_males={}
all_males['all'] = pd.read_excel("http://cosmo.nyu.edu/~fb55/PUI2016/data/pinc08_2_1_1.xls",skiprows=9)
all_males['white'] = pd.read_excel("http://cosmo.nyu.edu/~fb55/PUI2016/data/pinc08_2_1_4.xls",skiprows=9)
all_males['black'] = pd.read_excel("http://cosmo.nyu.edu/~fb55/PUI2016/data/pinc08_2_1_6.xls",skiprows=9)
all_males['asian'] = pd.read_excel("http://cosmo.nyu.edu/~fb55/PUI2016/data/pinc08_2_1_8.xls",skiprows=9)
all_males['hispanic'] = pd.read_excel("http://cosmo.nyu.edu/~fb55/PUI2016/data/pinc08_2_1_9.xls",skiprows=9)

all_females={}
all_females['all'] = pd.read_excel("http://cosmo.nyu.edu/~fb55/PUI2016/data/pinc08_3_1_1.xls",skiprows=9)
all_females['white'] = pd.read_excel("http://cosmo.nyu.edu/~fb55/PUI2016/data/pinc08_3_1_4.xls",skiprows=9)
all_females['black'] = pd.read_excel("http://cosmo.nyu.edu/~fb55/PUI2016/data/pinc08_3_1_6.xls",skiprows=9)
all_females['asian'] = pd.read_excel("http://cosmo.nyu.edu/~fb55/PUI2016/data/pinc08_3_1_8.xls",skiprows=9)
all_females['hispanic'] = pd.read_excel("http://cosmo.nyu.edu/~fb55/PUI2016/data/pinc08_3_1_9.xls",skiprows=9)

#for item in all_females:
#    all_females[item].dropna(inplace=True)

#for item in all_males:
#    all_males[item].dropna(inplace=True)

# %%
#all_females['all'].dropna(inplace=True)
all_females['all'].head(4)
# Out:
#        Characteristic  Total with Income  $1 to $2,499 or loss  \
# 0                 NaN                NaN                   NaN
# 1           ....Total           109956.0                7590.0
# 2            Earnings            74545.0                4198.0
# 3  ..Wages and Salary            71220.0                3835.0
#
#    $2,500 to $4,999  $5,000 to $7,499  $7,500 to $9,999  $10,000 to $12,499  \
# 0               NaN               NaN               NaN                 NaN
# 1            4298.0            5557.0            7874.0              8052.0
# 2            3118.0            3269.0            2662.0              4579.0
# 3            2954.0            3005.0            2411.0              4309.0
#
#    $12,500 to $14,999  $15,000 to $17,499  $17,500 to $19,999  \
# 0                 NaN                 NaN                 NaN
# 1              5720.0              6768.0              4377.0
# 2              1994.0              4134.0              2585.0
# ...

# %%
#all_males['all'].dropna(inplace=True)
all_males['all'].head(4)
# Out:
#        Characteristic  Total with Income  $1 to $2,499 or loss  \
# 0                 NaN                NaN                   NaN
# 1           ....Total           108706.0                4407.0
# 2            Earnings            83555.0                3217.0
# 3  ..Wages and Salary            78263.0                2779.0
#
#    $2,500 to $4,999  $5,000 to $7,499  $7,500 to $9,999  $10,000 to $12,499  \
# 0               NaN               NaN               NaN                 NaN
# 1            2665.0            3200.0            4027.0              4418.0
# 2            2326.0            2560.0            1964.0              3118.0
# 3            2184.0            2419.0            1780.0              2777.0
#
#    $12,500 to $14,999  $15,000 to $17,499  $17,500 to $19,999  \
# 0                 NaN                 NaN                 NaN
# 1              3333.0              5027.0              3807.0
# 2              1505.0              3451.0              1959.0
# ...

# %%
#the files are a bit of a mess! 
all_females['all'].columns
# Out:
# Index([      u'Characteristic',    u'Total with Income',
#        u'$1 to $2,499 or loss',     u'$2,500 to $4,999',
#            u'$5,000 to $7,499',     u'$7,500 to $9,999',
#          u'$10,000 to $12,499',   u'$12,500 to $14,999',
#          u'$15,000 to $17,499',   u'$17,500 to $19,999',
#          u'$20,000 to $22,499',   u'$22,500 to $24,999',
#          u'$25,000 to $27,499',   u'$27,500 to $29,999',
#          u'$30,000 to $32,499',   u'$32,500 to $34,999',
#          u'$35,000 to $37,499',   u'$37,500 to $39,999',
#          u'$40,000 to $42,499',   u'$42,500 to $44,999',
#          u'$45,000 to $47,499',   u'$47,500 to $49,999',
#          u'$50,000 to $52,499',   u'$52,500 to $54,999',
#          u'$55,000 to $57,499',   u'$57,500 to $59,999',
#          u'$60,000 to $62,499',   u'$62,500 to $64,999',
#          u'$65,000 to $67,499',   u'$67,500 to $69,999',
#          u'$70,000 to $72,499',   u'$72,500 to $74,999',
# ...

# %%
# just run this cell to get an idea of the data
for k,v in all_females.items():
    print("#####", k)
    print(v.describe())
for k,v in all_males.items():
    print("#####", k)
    print(v.describe())
# Out:
# ##### hispanic
#        Total with Income  $1 to $2,499 or loss  $2,500 to $4,999  \
# count          46.000000             46.000000         46.000000
# mean         1908.739130            274.282609        137.717391
# std          3688.718088            568.547923        199.157298
# min             1.000000              0.000000          0.000000
# 25%                  NaN                   NaN               NaN
# 50%                  NaN                   NaN               NaN
# 75%                  NaN                   NaN               NaN
# max         14034.000000           2704.000000        783.000000
#
#        $5,000 to $7,499  $7,500 to $9,999  $10,000 to $12,499  \
# count         46.000000         46.000000           46.000000
# mean         154.043478        188.913043          175.173913
# std          259.111813        321.948569          341.577016
# min            0.000000          0.000000            0.000000
# ...

# %%
# only columns containing real numerical values 
# are plotted with scatter_matrix. 
# But we are interested in median income but it wont get plotted, 
# due to bad values in the column

fig = pd.scatter_matrix(all_males['all']
                   [[u'Total with Income',u'$2,500 to $4,999',
                     u'Median income',u'Gini ratio']],
                   linewidth= 3, s=500, figsize=(15,15), 
                        diagonal='kde')

# %%
#the rel values in the Median income row are fewer than the number of rows
print (all_males['asian'].shape)
all_males['asian'].applymap(np.isreal).sum()
# Out:
# (49, 49)
# Characteristic           1
# Total with Income       49
# $1 to $2,499 or loss    49
# $2,500 to $4,999        49
# $5,000 to $7,499        49
# $7,500 to $9,999        49
# $10,000 to $12,499      49
# $12,500 to $14,999      49
# $15,000 to $17,499      49
# $17,500 to $19,999      49
# $20,000 to $22,499      49
# $22,500 to $24,999      49
# $25,000 to $27,499      49
# $27,500 to $29,999      49
# $30,000 to $32,499      49
# $32,500 to $34,999      49
# $35,000 to $37,499      49
# $37,500 to $39,999      49
# $40,000 to $42,499      49
# $42,500 to $44,999      49
# $45,000 to $47,499      49
# $47,500 to $49,999      49
# $50,000 to $52,499      49
# $52,500 to $54,999      49
# $55,000 to $57,499      49
# $57,500 to $59,999      49
# $60,000 to $62,499      49
# $62,500 to $64,999      49
# $65,000 to $67,499      49
# $67,500 to $69,999      49
# $70,000 to $72,499      49
# $72,500 to $74,999      49
# $75,000 to $77,499      49
# $77,500 to $79,999      49
# ...

# %%
# there are a lot of non-real values that make the analysis hard.
# the ugly loops below will help you clean up 
# CHALLENGE: can you do better and to it in a more pythonic way 
#            without using loops? 
#NOTE: this only will work if the data is store how I suggested. 
# you are welcome to find your own solution though.

for gender in [all_males, all_females]:
    for k in gender:
        # find non real values in the dataframe with applymap
        isreal  = gender[k].applymap(np.isreal)
        for c in gender[k].columns :
            #i f some but not all values in column are real
            #replace the non real ones
            if isreal.sum()[c] > 0 and \
            isreal.sum()[c] < gender[k].shape[0]:
                gender[k][c][~isreal[c]] =  np.nan
                gender[k][c] = gender[k][c].astype(float)
# Out:
# /opt/rh/anaconda/root/envs/PUI2016_Python2/lib/python2.7/site-packages/ipykernel/__main__.py:16: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy

# %%
fig = pd.scatter_matrix(all_males['all']
                   [[u'Total with Income',u'$2,500 to $4,999',
                     u'Median income',u'Gini ratio']],
                   linewidth= 3, s=500, figsize=(15,15), 
                        diagonal='kde')

# %%
fig = pd.scatter_matrix(all_females['all']
                   [[u'Total with Income',u'$2,500 to $4,999',
                     u'Median income',u'Gini ratio']],
                   linewidth= 3, s=500, figsize=(15,15), 
                        diagonal='kde')

# %%
fw = all_females['white'][u'Median income'][1]
fb = all_females['black'][u'Median income'][1]
fa = all_females['asian'][u'Median income'][1]
fh = all_females['hispanic'][u'Median income'][1]
mw = all_males['white'][u'Median income'][1]
mb = all_males['black'][u'Median income'][1]
ma = all_males['asian'][u'Median income'][1]
mh = all_males['hispanic'][u'Median income'][1]

fw.dropna(inplace=True)


#h = pd.concat(df.DataFrame(list(fw)),df.DataFrame(list(fb))
#print(h)

x_male = np.array([0,mw,mb,ma,mh])
x_female = np.array([0,fw,fb,fa,fh])

pl.scatter(x_male,x_female)

from scipy import stats

mall = all_males['all'][u'Median income'][1]
fall = all_females['all'][u'Median income'][1]

x_male = np.array([0,mall,mw,mb,ma,mh])
x_female = np.array([0,fall,fw,fb,fa,fh])

cor = stats.spearmanr(x_male, x_female)
beta1 = cor[0] * x_female.std() / x_male.std()
beta0 = x_female.mean() - beta1 * x_male.mean()

#beta0, beta1
print ("intercept = ", beta0)
print ("beta = ", beta1)

pl.plot([0,50000], [(beta0 + beta1*0), (beta0 + beta1*50000)], 'b-')
# Out:
# AttributeErrorTraceback (most recent call last)
# <ipython-input-42-2c367efc8897> in <module>()
#       8 mh = all_males['hispanic'][u'Median income'][1]
#       9
# ---> 10 fw.dropna(inplace=True)
#      11
#      12
#
# AttributeError: 'numpy.float64' object has no attribute 'dropna'

# %%
import statsmodels.formula.api as smf    # for OLS regression
#import matplotlib.pyplot as plt  # for data visualization
#%pylab inline


df=pd.concat([pd.DataFrame(x_male),pd.DataFrame(x_female)],axis=1)
df.columns = ['male_income','female_income']

lm2 = smf.ols("female_income ~ male_income", data=df).fit()
print(lm2.summary())
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:          female_income   R-squared:                       0.952
# Model:                            OLS   Adj. R-squared:                  0.940
# Method:                 Least Squares   F-statistic:                     78.78
# Date:                Mon, 10 Oct 2016   Prob (F-statistic):           0.000890
# Time:                        23:49:33   Log-Likelihood:                -53.651
# No. Observations:                   6   AIC:                             111.3
# Df Residuals:                       4   BIC:                             110.9
# Df Model:                           1
# Covariance Type:            nonrobust
# ...
#                   coef    std err          t      P>|t|      [95.0% Conf. Int.]
# -------------------------------------------------------------------------------
# Intercept    1674.6927   2066.985      0.810      0.463     -4064.179  7413.564
# ...

# %%
from scipy import stats


all_males_allincomes = np.array(
    np.concatenate([all_males['all']['Median income'][:].values,
                    all_males['white']['Median income'][:].values,
                    all_males['black']['Median income'][:].values,
                    all_males['hispanic']['Median income'][:].values,
                    all_males['asian']['Median income'][:].values]).flatten())
all_females_allincomes = np.array(
    np.concatenate([all_females['all']['Median income'][:].values,
                    all_females['white']['Median income'][:].values,
                    all_females['black']['Median income'][:].values,
                    all_females['hispanic']['Median income'][:].values,
                    all_females['asian']['Median income'][:].values]).flatten())
    
  
# with a list comprehension syntax, but the result i the same as above
    
#    np.concatenate([all_females[k]['Median income'][:].values \
#                    for k in ['all',
#                                   'white', 'black', 
#                                    'hispanic', 'asian']]).flatten())

#IDepending on what you use to fit you may need to remove NaN values 
#I am gonna create the mask in the next line. 
#the mask is False where either male or female value is NaN. 
#Notice that True is really just >1, and False really 0. 
#so i can add the male and female mask and the resulting mask will be 
#False where both arrays are not Nan, and true otherwise. 

mask = ~(np.isnan(all_males_allincomes) + np.isnan(all_females_allincomes))
# now you can use mask as an index (broadcasting) to select the non NaN values

# %%
ef=pd.concat([pd.DataFrame(all_males_allincomes),pd.DataFrame(all_females_allincomes)],axis=1)
ef.columns = ['male_income','female_income']

lm2 = smf.ols("female_income ~ male_income", data=ef).fit()
print(lm2.summary())
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:          female_income   R-squared:                       0.859
# Model:                            OLS   Adj. R-squared:                  0.859
# Method:                 Least Squares   F-statistic:                     1075.
# Date:                Mon, 10 Oct 2016   Prob (F-statistic):           7.21e-77
# Time:                        23:49:36   Log-Likelihood:                -1668.8
# No. Observations:                 178   AIC:                             3342.
# Df Residuals:                     176   BIC:                             3348.
# Df Model:                           1
# Covariance Type:            nonrobust
# ...
#                   coef    std err          t      P>|t|      [95.0% Conf. Int.]
# -------------------------------------------------------------------------------
# Intercept    1493.0394    351.359      4.249      0.000       799.619  2186.459
# ...

# %%
i, b = lm2.params

# %%
print(i, b)
# Out:
# 1493.03944114 0.609020523617

# %%
male_stipend = 200000

# %%
female_stipend = i+b*male_stipend

# %%
female_stipend
# Out:
# 123297.14416464244

# %% [markdown]
# #### if a man makes 200,000 dollars per year, a women is predicted to make 123,297.

# %%
pl.scatter(all_males_allincomes,all_females_allincomes)
pl.plot([0,50000], [(i + b*0), (i + b*50000)], 'b-')

# %% [markdown]
# ### women make 60% of what men make.

# %%
all_males['black']['Median income'].dropna(inplace=True)
all_females['black']['Median income'].dropna(inplace=True)

stats.ttest_ind(all_males['black']['Median income'][:].values, all_females['black']['Median income'][:].values)
# Out:
# Ttest_indResult(statistic=1.2342247304601184, pvalue=0.22118881868233467)

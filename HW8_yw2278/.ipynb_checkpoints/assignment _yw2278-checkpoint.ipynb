# 77                    New York City Police Department
# 78                       Department of Transportation
# 79                       Department of Transportation
# 80                    New York City Police Department
# 81                    New York City Police Department
# 82                    New York City Police Department
# 83                    New York City Police Department
# 84                    New York City Police Department
# 85                                  Commissioner - EC
# 86                    New York City Police Department
# 87                    New York City Police Department
# 88                    New York City Police Department
# 89  Department of Housing Preservation and Develop...
# 90                       Department of Transportation
# 91                    New York City Police Department
# 92                    New York City Police Department
# 93                    New York City Police Department
# 94                    New York City Police Department
# 95                    New York City Police Department
# 96                    New York City Police Department
# 97                    New York City Police Department
# 98                    New York City Police Department
# 99                    New York City Police Department
#
#                    Complaint Type                      Descriptor  \
# 0                Street Condition                         Pothole
# 1           Opinion for the Mayor                         HOUSING
# 2   Root/Sewer/Sidewalk Condition     Trees and Sidewalks Program
# 3                 Illegal Parking                 Blocked Hydrant
# 4        Benefit Card Replacement                        Medicaid
# 5               Highway Condition               Pothole - Highway
# 6                   Agency Issues              New Tree Complaint
# 7              Noise - Commercial                Loud Music/Party
# 8              Noise - Commercial                Loud Music/Party
# 9              Noise - Commercial                Loud Music/Party
# 10               Blocked Driveway                       No Access
# 11                 Taxi Complaint                Driver Complaint
# 12               Blocked Driveway                       No Access
# 13               Blocked Driveway                       No Access
# 14             Noise - Commercial                Loud Music/Party
# 15               Blocked Driveway                       No Access
# 16             Noise - Commercial                Banging/Pounding
# 17                Illegal Parking                Blocked Sidewalk
# 18             Noise - Commercial                Loud Music/Party
# 19               Blocked Driveway                       No Access
# 20                Illegal Parking    Commercial Overnight Parking
# 21                   Damaged Tree  Branch or Limb Has Fallen Down
# 22        Noise - Street/Sidewalk                    Loud Talking
# 23               Blocked Driveway                       No Access
# 24                 Taxi Complaint                Driver Complaint
# 25             Noise - Commercial                Loud Music/Party
# 26       Traffic Signal Condition              Ped Multiple Lamps
# 27                Illegal Parking                 Blocked Hydrant
# 28       Traffic Signal Condition              Ped Multiple Lamps
# 29                Illegal Parking                 Blocked Hydrant
# ..                            ...                             ...
# 70          Opinion for the Mayor                         HOUSING
# 71          Posting Advertisement                        Building
# 72          Opinion for the Mayor                    PUBLICSAFETY
# 73               Street Condition            Failed Street Repair
# 74            Homeless Encampment                             NaN
# 75        Noise - Street/Sidewalk                Loud Music/Party
# 76               Blocked Driveway                       No Access
# 77                Illegal Parking        Unauthorized Bus Layover
# 78         Street Light Condition                Street Light Out
# 79               Street Condition                         Pothole
# 80             Noise - Commercial                Loud Music/Party
# 81        Noise - Street/Sidewalk                Loud Music/Party
# 82             Noise - Commercial                Loud Music/Party
# 83                Illegal Parking                Blocked Sidewalk
# 84                Illegal Parking    Commercial Overnight Parking
# 85                  Agency Issues               Enforcement Issue
# 86        Noise - Street/Sidewalk                    Loud Talking
# 87                Illegal Parking        Unauthorized Bus Layover
# 88               Blocked Driveway                  Partial Access
# 89                 HEAT/HOT WATER                 ENTIRE BUILDING
# 90         Street Light Condition                Street Light Out
# 91             Noise - Commercial                Loud Music/Party
# 92               Blocked Driveway                       No Access
# 93             Noise - Commercial                Loud Music/Party
# 94        Noise - Street/Sidewalk                Loud Music/Party
# 95        Noise - Street/Sidewalk                    Loud Talking
# 96                Illegal Parking    Commercial Overnight Parking
# 97               Blocked Driveway                       No Access
# 98                Noise - Vehicle                  Car/Truck Horn
# 99               Blocked Driveway                       No Access
#
#                  Location Type Incident Zip            Incident Address  \
# 0                          NaN        11224                         NaN
# 1                          NaN          NaN                         NaN
# 2                       Street        11234         1157 EAST 57 STREET
# 3              Street/Sidewalk        11218           722 EAST 4 STREET
# 4           NYC Street Address          NaN                         NaN
# 5                      Highway        10304                         NaN
# 6                          NaN          NaN                         NaN
# 7          Club/Bar/Restaurant        10021               1402 2 AVENUE
# 8             Store/Commercial        11231            273 SMITH STREET
# 9             Store/Commercial        11231            273 SMITH STREET
# 10             Street/Sidewalk        10465         279 PRENTISS AVENUE
# 11                         NaN        10022                850 3 AVENUE
# 12             Street/Sidewalk        11221             23 CEDAR STREET
# 13             Street/Sidewalk        11373             79-10 ELKS ROAD
# 14         Club/Bar/Restaurant        10027               3155 BROADWAY
# 15             Street/Sidewalk        11210         1557 EAST 23 STREET
# 16            Store/Commercial        10036          204 WEST 47 STREET
# 17             Street/Sidewalk        11230           657 OCEAN PARKWAY
# 18         Club/Bar/Restaurant        10013             32 WATTS STREET
# 19             Street/Sidewalk        11419           104-30 109 STREET
# 20             Street/Sidewalk        11358            43-20 167 STREET
# 21                         NaN        11101           23-16 45TH AVENUE
# 22             Street/Sidewalk        10010          123 EAST 24 STREET
# 23             Street/Sidewalk        11214            76 BAY 31 STREET
# 24                         NaN        11385                         NaN
# 25         Club/Bar/Restaurant        11207          123 JAMAICA AVENUE
# 26                         NaN        11385                         NaN
# 27             Street/Sidewalk        11415            84-46 130 STREET
# 28                         NaN        11385                         NaN
# 29             Street/Sidewalk        11415            84-39 130 STREET
# ..                         ...          ...                         ...
# 70                         NaN          NaN                         NaN
# 71  Residential Building/House        11219              1264 44 STREET
# 72                         NaN          NaN                         NaN
# 73                      Street        10016          240 EAST 32 STREET
# 74             Street/Sidewalk        11226           2160 CATON AVENUE
# 75             Street/Sidewalk        10031         560 WEST 144 STREET
# 76             Street/Sidewalk        11412           111-21 205 STREET
# 77             Street/Sidewalk        11219  4305 FORT HAMILTON PARKWAY
# 78                         NaN        11212                         NaN
# 79                         NaN        11436                         NaN
# 80         Club/Bar/Restaurant        10025                         NaN
# 81             Street/Sidewalk        10025         107 WEST 109 STREET
# 82         Club/Bar/Restaurant        10002             39 ESSEX STREET
# 83             Street/Sidewalk        11358                   33 AVENUE
# 84             Street/Sidewalk        11224                         NaN
# 85                         NaN          NaN                         NaN
# 86             Street/Sidewalk        10030   672 SAINT NICHOLAS AVENUE
# 87             Street/Sidewalk        11218  4024 FORT HAMILTON PARKWAY
# 88             Street/Sidewalk        11236          735 EAST 82 STREET
# 89        RESIDENTIAL BUILDING        11385          1819 GEORGE STREET
# 90                         NaN        11367                         NaN
# 91         Club/Bar/Restaurant        10012        281 LAFAYETTE STREET
# 92             Street/Sidewalk        11385             64-30 68 AVENUE
# 93         Club/Bar/Restaurant        10036               667 10 AVENUE
# 94             Street/Sidewalk        10459                         NaN
# 95             Street/Sidewalk        11233          651 HANCOCK STREET
# 96             Street/Sidewalk        11691      1122 GRASSMERE TERRACE
# 97             Street/Sidewalk        10026         318 WEST 118 STREET
# 98             Street/Sidewalk        11209               601 79 STREET
# 99             Street/Sidewalk        11373         41-07 DENMAN STREET
#
#                       ...                     Bridge Highway Name  \
# 0                     ...                                     NaN
# 1                     ...                                     NaN
# 2                     ...                                     NaN
# 3                     ...                                     NaN
# 4                     ...                                     NaN
# 5                     ...                     Staten Island Expwy
# 6                     ...                                     NaN
# 7                     ...                                     NaN
# 8                     ...                                     NaN
# 9                     ...                                     NaN
# 10                    ...                                     NaN
# 11                    ...                                     NaN
# 12                    ...                                     NaN
# 13                    ...                                     NaN
# 14                    ...                                     NaN
# 15                    ...                                     NaN
# 16                    ...                                     NaN
# 17                    ...                                     NaN
# 18                    ...                                     NaN
# 19                    ...                                     NaN
# 20                    ...                                     NaN
# 21                    ...                                     NaN
# 22                    ...                                     NaN
# 23                    ...                                     NaN
# 24                    ...                                     NaN
# 25                    ...                                     NaN
# 26                    ...                                     NaN
# 27                    ...                                     NaN
# 28                    ...                                     NaN
# 29                    ...                                     NaN
# ..                    ...                                     ...
# 70                    ...                                     NaN
# 71                    ...                                     NaN
# 72                    ...                                     NaN
# 73                    ...                                     NaN
# 74                    ...                                     NaN
# 75                    ...                                     NaN
# 76                    ...                                     NaN
# 77                    ...                                     NaN
# 78                    ...                                     NaN
# 79                    ...                                     NaN
# 80                    ...                                     NaN
# 81                    ...                                     NaN
# 82                    ...                                     NaN
# 83                    ...                                     NaN
# 84                    ...                                     NaN
# 85                    ...                                     NaN
# 86                    ...                                     NaN
# 87                    ...                                     NaN
# 88                    ...                                     NaN
# 89                    ...                                     NaN
# 90                    ...                                     NaN
# 91                    ...                                     NaN
# 92                    ...                                     NaN
# 93                    ...                                     NaN
# 94                    ...                                     NaN
# 95                    ...                                     NaN
# 96                    ...                                     NaN
# 97                    ...                                     NaN
# 98                    ...                                     NaN
# 99                    ...                                     NaN
#
#    Bridge Highway Direction Road Ramp  \
# 0                       NaN       NaN
# 1                       NaN       NaN
# 2                       NaN       NaN
# 3                       NaN       NaN
# 4                       NaN       NaN
# 5       East/Brooklyn Bound   Roadway
# 6                       NaN       NaN
# 7                       NaN       NaN
# 8                       NaN       NaN
# 9                       NaN       NaN
# 10                      NaN       NaN
# 11                      NaN       NaN
# 12                      NaN       NaN
# 13                      NaN       NaN
# 14                      NaN       NaN
# 15                      NaN       NaN
# 16                      NaN       NaN
# 17                      NaN       NaN
# 18                      NaN       NaN
# 19                      NaN       NaN
# 20                      NaN       NaN
# 21                      NaN       NaN
# 22                      NaN       NaN
# 23                      NaN       NaN
# 24                      NaN       NaN
# 25                      NaN       NaN
# 26                      NaN       NaN
# 27                      NaN       NaN
# 28                      NaN       NaN
# 29                      NaN       NaN
# ..                      ...       ...
# 70                      NaN       NaN
# 71                      NaN       NaN
# 72                      NaN       NaN
# 73                      NaN       NaN
# 74                      NaN       NaN
# 75                      NaN       NaN
# 76                      NaN       NaN
# 77                      NaN       NaN
# 78                      NaN       NaN
# 79                      NaN       NaN
# 80                      NaN       NaN
# 81                      NaN       NaN
# 82                      NaN       NaN
# 83                      NaN       NaN
# 84                      NaN       NaN
# 85                      NaN       NaN
# 86                      NaN       NaN
# 87                      NaN       NaN
# 88                      NaN       NaN
# 89                      NaN       NaN
# 90                      NaN       NaN
# 91                      NaN       NaN
# 92                      NaN       NaN
# 93                      NaN       NaN
# 94                      NaN       NaN
# 95                      NaN       NaN
# 96                      NaN       NaN
# 97                      NaN       NaN
# 98                      NaN       NaN
# 99                      NaN       NaN
#
#                                Bridge Highway Segment Garage Lot Name  \
# 0                                                 NaN             NaN
# 1                                      1-1-1173130914             NaN
# 2                                                 NaN             NaN
# 3                                                 NaN             NaN
# 4                                                 NaN             NaN
# 5   Clove Rd/Richmond Rd (Exit 13) - Lily Pond Ave...             NaN
# 6                                                 NaN             NaN
# 7                                                 NaN             NaN
# 8                                                 NaN             NaN
# 9                                                 NaN             NaN
# 10                                                NaN             NaN
# 11                                                NaN             NaN
# 12                                                NaN             NaN
# 13                                                NaN             NaN
# 14                                                NaN             NaN
# 15                                                NaN             NaN
# 16                                                NaN             NaN
# 17                                                NaN             NaN
# 18                                                NaN             NaN
# 19                                                NaN             NaN
# 20                                                NaN             NaN
# 21                                                NaN             NaN
# 22                                                NaN             NaN
# 23                                                NaN             NaN
# 24                                                NaN             NaN
# 25                                                NaN             NaN
# 26                                                NaN             NaN
# 27                                                NaN             NaN
# 28                                                NaN             NaN
# 29                                                NaN             NaN
# ..                                                ...             ...
# 70                                     1-1-1173130684             NaN
# 71                                                NaN             NaN
# 72                                     1-1-1173130679             NaN
# 73                                                NaN             NaN
# 74                                                NaN             NaN
# 75                                                NaN             NaN
# 76                                                NaN             NaN
# 77                                                NaN             NaN
# 78                                                NaN             NaN
# 79                                                NaN             NaN
# 80                                                NaN             NaN
# 81                                                NaN             NaN
# 82                                                NaN             NaN
# 83                                                NaN             NaN
# 84                                                NaN             NaN
# 85                                                NaN             NaN
# 86                                                NaN             NaN
# 87                                                NaN             NaN
# 88                                                NaN             NaN
# 89                                                NaN             NaN
# 90                                                NaN             NaN
# 91                                                NaN             NaN
# 92                                                NaN             NaN
# 93                                                NaN             NaN
# 94                                                NaN             NaN
# 95                                                NaN             NaN
# 96                                                NaN             NaN
# 97                                                NaN             NaN
# 98                                                NaN             NaN
# 99                                                NaN             NaN
#
#    Ferry Direction Ferry Terminal Name   Latitude  Longitude  \
# 0              NaN                 NaN  40.573431 -73.991742
# 1              NaN                 NaN        NaN        NaN
# 2              NaN                 NaN  40.625004 -73.920726
# 3              NaN                 NaN  40.634522 -73.974790
# 4              NaN                 NaN        NaN        NaN
# 5              NaN                 NaN  40.606875 -74.085408
# 1                      HOUSING                 NaN          NaN
# 2  Trees and Sidewalks Program              Street        11234
# 3              Blocked Hydrant     Street/Sidewalk        11218
# 4                     Medicaid  NYC Street Address          NaN
#
#       Incident Address                    ...                     \
# 0                  NaN                    ...
# 1                  NaN                    ...
# 2  1157 EAST 57 STREET                    ...
# 3    722 EAST 4 STREET                    ...
# 4                  NaN                    ...
#
#   Bridge Highway Name Bridge Highway Direction Road Ramp  \
# 0                 NaN                      NaN       NaN
# 1                 NaN                      NaN       NaN
# 2                 NaN                      NaN       NaN
# 3                 NaN                      NaN       NaN
# 4                 NaN                      NaN       NaN
#
#   Bridge Highway Segment Garage Lot Name Ferry Direction Ferry Terminal Name  \
# 0                    NaN             NaN             NaN                 NaN
# 1         1-1-1173130914             NaN             NaN                 NaN
# 2                    NaN             NaN             NaN                 NaN
# 3                    NaN             NaN             NaN                 NaN
# 4                    NaN             NaN             NaN                 NaN
#
#     Latitude  Longitude                                  Location
# 0  40.573431 -73.991742   (40.57343122248129, -73.99174247588253)
# 1        NaN        NaN                                       NaN
# 2  40.625004 -73.920726   (40.62500363580505, -73.92072558378698)
# 3  40.634522 -73.974790  (40.634522428879706, -73.97479041437481)
# 4        NaN        NaN                                       NaN
#
# [5 rows x 53 columns]

# %%
len(datareduced["Community Board"].unique())
# Out:
# 77

# %%
datareduced["Community Board"].unique()
# Out:
# array(['13 BROOKLYN', '0 Unspecified', '18 BROOKLYN', '12 BROOKLYN',
#        '02 STATEN ISLAND', '08 MANHATTAN', '06 BROOKLYN', '10 BRONX',
#        '06 MANHATTAN', '04 BROOKLYN', '04 QUEENS', '09 MANHATTAN',
#        '14 BROOKLYN', '05 MANHATTAN', '02 MANHATTAN', '10 QUEENS',
#        '07 QUEENS', '02 QUEENS', '11 BROOKLYN', '05 QUEENS', '05 BROOKLYN',
#        '09 QUEENS', '12 MANHATTAN', '01 BROOKLYN', '11 MANHATTAN',
#        '03 BRONX', '03 STATEN ISLAND', '08 BROOKLYN', '03 BROOKLYN',
#        '07 MANHATTAN', '10 MANHATTAN', '04 BRONX', '01 MANHATTAN',
#        '07 BRONX', '09 BRONX', '03 MANHATTAN', '13 QUEENS', '02 BRONX',
#        '12 QUEENS', '16 BROOKLYN', '08 QUEENS', '04 MANHATTAN',
#        '14 QUEENS', '10 BROOKLYN', '11 QUEENS', '06 BRONX', '08 BRONX',
#        '05 BRONX', '15 BROOKLYN', '02 BROOKLYN', '12 BRONX', '03 QUEENS',
#        '06 QUEENS', '01 STATEN ISLAND', '01 BRONX', '01 QUEENS',
#        '17 BROOKLYN', '11 BRONX', 'Unspecified QUEENS', '09 BROOKLYN',
#        'Unspecified MANHATTAN', 'Unspecified BROOKLYN', '07 BROOKLYN',
#        'Unspecified BRONX', '64 MANHATTAN', '81 QUEENS', '55 BROOKLYN',
#        '83 QUEENS', 'Unspecified STATEN ISLAND', '28 BRONX', '80 QUEENS',
#        '26 BRONX', '95 STATEN ISLAND', '82 QUEENS', '27 BRONX',
#        '56 BROOKLYN', '84 QUEENS'], dtype=object)

# %% [markdown]
# #### How many unique values do we have?
# There are 74 unique community districts in the data.
# #### Why do we have so many? Some of them are unspecified, missing. Some might be invalid entries. (We should have 59 Community Districts.)
# There are more than 59 unique values because some are 'unspecified'. All boroughs are represented, however Staten Island only has one Community District included in the data.

# %%
len(datareduced)
# Out:
# 10187766

# %%
datareduced.drop_duplicates().shape
# Out:
# (10187766, 53)

# %% [markdown]
# #### There are no duplicate rows in this dataset.

# %%
datareduced.isnull().sum()
# Out:
# Unique Key                               0
# Created Date                             0
# Closed Date                         450879
# Agency                                   0
# Agency Name                              0
# Complaint Type                           0
# Descriptor                           31057
# Location Type                      3067596
# Incident Zip                        794159
# Incident Address                   2197706
# Street Name                        2198559
# Cross Street 1                     2375943
# Cross Street 2                     2425793
# Intersection Street 1              8345288
# Intersection Street 2              8346302
# Address Type                        490299
# City                                788712
# Landmark                          10180456
# Facility Type                      8579485
# Status                                   0
# Due Date                           7120286
# Resolution Description             3786751
# Resolution Action Updated Date      250934
# Community Board                          0
# Borough                                  0
# X Coordinate (State Plane)          878752
# Y Coordinate (State Plane)          878752
# Park Facility Name                       0
# Park Borough                             0
# School Name                              0
# School Number                         2283
# School Region                        56197
# School Code                          56196
# School Phone Number                      0
# School Address                           6
# School City                              0
# School State                             0
# School Zip                               5
# School Not Found                   7151698
# School or Citywide Complaint      10185412
# Vehicle Type                      10180264
# Taxi Company Borough              10177601
# Taxi Pick Up Location             10089207
# Bridge Highway Name               10152671
# Bridge Highway Direction          10152723
# Road Ramp                         10152986
# Bridge Highway Segment            10135780
# Garage Lot Name                   10183433
# Ferry Direction                   10185023
# Ferry Terminal Name               10181242
# Latitude                            878752
# Longitude                           878752
# Location                            878752
# dtype: int64

# %% [markdown]
# There are cells with missing values. Columns 'Landmark', 'School or Citywide Complaint', 'Vehicle Type', 'Taxi Company Borough', 'Garage Lot Name', 'Ferry Direction', and 'Ferry Terminal Name' contain exclusively null values. Similarly, 'Bridge Highway Name', 'Bridge Highway Direction', and 'Road Ramp' only contain one non-null value. Community Board does not have any null values.

# %%
datareduced["Resolution Description"].fillna(datareduced["Complaint Type"], inplace=True)

# %%
datareduced["Resolution Description"].isnull().sum()
# Out:
# 0

# %% [markdown]
# #### The unplausible Community Districts are those which include the word 'unspecified' in the title and the Community Districts with numbers greater than 18

# %%
def flag(data):
    if re.search(r"Unspecified", data):
        return 0
    elif int(re.search(r"(\d\d*)\s\w+", data).group(1))>18:
        return 0
    else:
        return 1

# %%
mask = datareduced["Community Board"].apply(flag)

# %%
datareduced["masks"] = mask

# %%
datanew = datareduced[datareduced.masks==1]

# %%
datanew["Community Board"].unique().shape
# Out:
# (59,)

# %%
ranks = datanew["Complaint Type"].groupby(datanew["Community Board"]).count()

# %%
ranks = pd.DataFrame(ranks)

# %%
ranking = ranks.reset_index().sort(columns=["Complaint Type"], ascending=False).reset_index(drop=True)
# Out:
# /opt/rh/anaconda/root/envs/PUI2016_Python3/lib/python3.5/site-packages/ipykernel/__main__.py:1: FutureWarning: sort(columns=....) is deprecated, use sort_values(by=.....)
#   if __name__ == '__main__':

# %%
ranking = ranking.rename(columns = {'Complaint Type':'counts'})

# %%
ranking.head()
# Out:
#   Community Board  counts
# 0    12 MANHATTAN  268053
# 1       12 QUEENS  229383
# 2     03 BROOKLYN  197306
# 3       07 QUEENS  195961
# 4     17 BROOKLYN  191720

# %%
df_pop = pd.read_csv(PUIdata + "/Final_Demographics.csv")
df_infr = pd.read_csv(PUIdata + "/ACS_Computer_Use_and_Internet_2014_1Year_Estimate.csv")

# %%
df_infr.head()
# Out:
#       FIPS Geographic Identifier  \
# 0  3603701        79500US3603701
# 1  3603702        79500US3603702
# 2  3603703        79500US3603703
# 3  3603704        79500US3603704
# 4  3603705        79500US3603705
#
#                                      Qualifying Name  Households  \
# 0  NYC-Bronx Community District 8--Riverdale, New...       42035
# 1  NYC-Bronx Community District 12--Wakefield, Ne...       44830
# 2  NYC-Bronx Community District 10--Co-op City, N...       47050
# 3  NYC-Bronx Community District 11--Pelham Parkwa...       44922
# 4  NYC-Bronx Community District 3 & 6--Belmont, N...       57556
#
#    Households: With An Internet Subscription  Households: Dial-Up Alone  \
# 0                                      31795                        444
# 1                                      32243                        178
# 2                                      32729                        158
# 3                                      32003                        141
# 4                                      35503                         88
#
#    Households: Dsl  Households: With Mobile Broadband  \
# 0             2813                                946
# 1              849                                405
# 2             1863                                398
# 3             1478                                474
# 4             1297                                651
#
#    Households: Without Mobile Broadband  Households: Cable Modem  \
# 0                                  1867                    19178
# 1                                   444                    18653
# 2                                  1465                    20044
# 3                                  1004                    17917
# 4                                   646                    15847
#
#             ...             Households: Mobile Broadband Alone or With Dialup  \
# 0           ...                                                          2168
# 1           ...                                                           928
# 2           ...                                                           639
# 3           ...                                                          1001
# 4           ...                                                          1385
#
#    Households: Internet Access Without A Subscription  \
# 0                                               2119
# 1                                               1891
# 2                                               2882
# 3                                               2722
# 4                                               3312
#
#    Households: No Internet Access  \
# 0                            8121
# 1                           10696
# 2                           11439
# 3                           10197
# 4                           18741
#
#    % Households: With An Internet Subscription  Households.1  \
# 0                                        75.64         42035
# 1                                        71.92         44830
# 2                                        69.56         47050
# 3                                        71.24         44922
# 4                                        61.68         57556
#
#    Households: Has A Computer  \
# 0                       35048
# 1                       36700
# 2                       38700
# 3                       37237
# 4                       42576
#
#    Households: With Dial-Up Internet Subscription Alone  \
# 0                                                404
# 1                                                178
# 2                                                158
# 3                                                122
# 4                                                 88
#
#    Households: With A Broadband Internet Subscription  \
# 0                                              30943
# 1                                              31435
# 2                                              32333
# 3                                              31278
# 4                                              33408
#
#    Households: Without An Internet Subscription  Households: No Computer
# 0                                          3701                     6987
# 1                                          5087                     8130
# 2                                          6209                     8350
# 3                                          5837                     7685
# 4                                          9080                    14980
#
# [5 rows x 31 columns]

# %%
df_pop.head()
# Out:
#       FIPS cd_id  Total Population  Population Density (per sq. mile)  \
# 0  3603701  BX08            106737                        31229.95006
# 1  3603702  BX12            134644                        19966.67839
# 2  3603703  BX10            121209                        12913.81703
# 3  3603704  BX11            135839                        35677.95453
# 4  3603705  BX03            172247                        39405.79222
#
#    % Total Population: Male  % Total Population: 18 to 24 Years  \
# 0                     46.65                               10.73
# 1                     46.35                               11.35
# 2                     45.20                                8.62
# 3                     50.09                                8.10
# 4                     44.72                               14.24
#
#    % Total Population: 25 to 34 Years  % Total Population: 35 to 44 Years  \
# 0                               15.04                               11.32
# 1                               14.29                               12.57
# 2                               13.74                               12.78
# 3                               17.43                               14.09
# 4                               14.89                               12.38
#
#    % Population 5 Years And Over: Speak Only English  \
# 0                                              46.80
# 1                                              73.09
# 2                                              61.79
# 3                                              43.22
# 4                                              36.82
#
#    % Population 5 Years And Over: Spanish or Spanish Creole  \
# 0                                              39.24
# 1                                              18.19
# 2                                              26.43
# 3                                              36.45
# 4                                              54.24
#
#                                                                                 ...                                                                                \
# 0                                                                               ...
# 1                                                                               ...
# 2                                                                               ...
# 3                                                                               ...
# 4                                                                               ...
#
#    Employed Civilian Population 16 Years And Over: Production, transportation, and material moving  occupations: Production occupations  \
# 0                                                665
# 1                                               1156
# 2                                                941
# 3                                               2189
# 4                                               1437
#
#    Employed Civilian Population 16 Years And Over: Production, transportation, and material moving  occupations: Transportation and material moving occupations  \
# 0                                               1518
# 1                                               4174
# 2                                               3433
# 3                                               5592
# 4                                               5436
#
#    % Employed Civilian Population 16 Years And Over: Management, professional, and related occupations  \
# 0                                              42.66
# 1                                              29.57
# 2                                              36.20
# 3                                              30.06
# 4                                              16.80
#
#    % Employed Civilian Population 16 Years And Over: Service occupations  \
# 0                                              28.95
# 1                                              33.98
# 2                                              22.85
# 3                                              27.86
# 4                                              41.00
#
#    % Employed Civilian Population 16 Years And Over: Sales and office occupations  \
# 0                                              20.89
# 1                                              20.40
# 2                                              25.09
# 3                                              22.24
# 4                                              22.29
#
#    % Employed Civilian Population 16 Years And Over: Farming, fishing, and forestry occupations  \
# 0                                               0.24
# 1                                               0.00
# 2                                               0.00
# 3                                               0.00
# 4                                               0.03
#
#    % Employed Civilian Population 16 Years And Over: Construction, extraction, and maintenance  occupations  \
# 0                                               2.65
# 1                                               7.08
# 2                                               7.68
# 3                                               7.03
# 4                                               8.45
#
#    % Employed Civilian Population 16 Years And Over: Production, transportation, and material moving  occupations  \
# 0                                               4.60
# 1                                               8.97
# 2                                               8.18
# 3                                              12.81
# 4                                              11.43
#
#    % Employed Civilian Population 16 Years And Over: Production, transportation, and material moving  occupations: Production occupations  \
# 0                                               1.40
# 1                                               1.95
# 2                                               1.76
# 3                                               3.60
# 4                                               2.39
#
#    % Employed Civilian Population 16 Years And Over: Production, transportation, and material moving  occupations: Transportation and material moving occupations
# 0                                               3.20
# 1                                               7.02
# 2                                               6.42
# 3                                               9.20
# 4                                               9.04
#
# [5 rows x 158 columns]

# %%
df_pop.columns
# Out:
# Index(['FIPS', 'cd_id', 'Total Population',
#        'Population Density (per sq. mile)', '% Total Population: Male',
#        '% Total Population: 18 to 24 Years',
#        '% Total Population: 25 to 34 Years',
#        '% Total Population: 35 to 44 Years',
#        '% Population 5 Years And Over: Speak Only English',
#        '% Population 5 Years And Over: Spanish or Spanish Creole',
#        ...
#        'Employed Civilian Population 16 Years And Over: Production, transportation, and material moving  occupations: Production occupations',
#        'Employed Civilian Population 16 Years And Over: Production, transportation, and material moving  occupations: Transportation and material moving occupations',
#        '% Employed Civilian Population 16 Years And Over: Management, professional, and related occupations',
#        '% Employed Civilian Population 16 Years And Over: Service occupations',
#        '% Employed Civilian Population 16 Years And Over: Sales and office occupations',
#        '% Employed Civilian Population 16 Years And Over: Farming, fishing, and forestry occupations',
#        '% Employed Civilian Population 16 Years And Over: Construction, extraction, and maintenance  occupations',
#        '% Employed Civilian Population 16 Years And Over: Production, transportation, and material moving  occupations',
#        '% Employed Civilian Population 16 Years And Over: Production, transportation, and material moving  occupations: Production occupations',
#        '% Employed Civilian Population 16 Years And Over: Production, transportation, and material moving  occupations: Transportation and material moving occupations'],
#       dtype='object', length=158)

# %%
df_pop["cd_id"].unique().shape
# Out:
# (59,)

# %%
demograph = df_pop[["cd_id", "Median household income (In 2014 Inflation Adjusted Dollars)"]]

# %% [markdown]
# #### Normally order people or people with families tend to make compliants

# %%
df_infr.columns
# Out:
# Index(['FIPS', 'Geographic Identifier', 'Qualifying Name', 'Households',
#        'Households: With An Internet Subscription',
#        'Households: Dial-Up Alone', 'Households: Dsl',
#        'Households: With Mobile Broadband',
#        'Households: Without Mobile Broadband', 'Households: Cable Modem',
#        'Households: With Mobile Broadband.1',
#        'Households: Without Mobile Broadband.1', 'Households: Fiber-Optic',
#        'Households: With Mobile Broadband.2',
#        'Households: Without Mobile Broadband.2',
#        'Households: Satellite Internet Service',
#        'Households: With Mobile Broadband.3',
#        'Households: Without Mobile Broadband.3',
#        'Households: Two or More Fixed Broadband Types, or Other',
#        'Households: With Mobile Broadband.4',
#        'Households: Without Mobile Broadband.4',
#        'Households: Mobile Broadband Alone or With Dialup',
#        'Households: Internet Access Without A Subscription',
#        'Households: No Internet Access',
#        '% Households: With An Internet Subscription', 'Households.1',
#        'Households: Has A Computer',
#        'Households: With Dial-Up Internet Subscription Alone',
#        'Households: With A Broadband Internet Subscription',
#        'Households: Without An Internet Subscription',
#        'Households: No Computer'],
#       dtype='object')

# %%
df_infr["Qualifying Name"].unique().shape
# Out:
# (55,)

# %%
mobile = df_infr.iloc[:,[2, 7, 10, 13, 16, 19, 21]]

# %%
mobile['Mobile'] = mobile.sum(axis=1)
# Out:
# /opt/rh/anaconda/root/envs/PUI2016_Python3/lib/python3.5/site-packages/ipykernel/__main__.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   if __name__ == '__main__':

# %%
# no mobile
nobile =  df_infr.iloc[:,[2, 8, 11, 14, 17, 20, 22]]

# %%
nobile['Nobile'] = nobile.sum(axis=1)
# Out:
# /opt/rh/anaconda/root/envs/PUI2016_Python3/lib/python3.5/site-packages/ipykernel/__main__.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   if __name__ == '__main__':

# %%
mobile_info = pd.concat([mobile, nobile], axis=1)

# %%
mobile_info = mobile_info.iloc[:,[0, 7, 15]]

# %%
mobile_info.head()
# Out:
#                                      Qualifying Name  Mobile  Nobile
# 0  NYC-Bronx Community District 8--Riverdale, New...   17527   15943
# 1  NYC-Bronx Community District 12--Wakefield, Ne...   11414   22542
# 2  NYC-Bronx Community District 10--Co-op City, N...   12064   23389
# 3  NYC-Bronx Community District 11--Pelham Parkwa...   11749   22835
# 4  NYC-Bronx Community District 3 & 6--Belmont, N...   16292   22435

# %%
high_speed =  df_infr.iloc[:,[2, 6, 9, 12]]
high_speed['High'] = high_speed.sum(axis=1)
low_speed = df_infr.iloc[:, [2, 5, 15]]
low_speed['Low'] = low_speed.sum(axis=1)
it_info = pd.concat([high_speed, low_speed], axis=1)
it_info = it_info.ix[:,[0,4, 8]]
# Out:
# /opt/rh/anaconda/root/envs/PUI2016_Python3/lib/python3.5/site-packages/ipykernel/__main__.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   from ipykernel import kernelapp as app
# /opt/rh/anaconda/root/envs/PUI2016_Python3/lib/python3.5/site-packages/ipykernel/__main__.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy

# %%
it_info.head()
# Out:
#                                      Qualifying Name   High  Low
# 0  NYC-Bronx Community District 8--Riverdale, New...  22930  519
# 1  NYC-Bronx Community District 12--Wakefield, Ne...  25718  309
# 2  NYC-Bronx Community District 10--Co-op City, N...  25397  158
# 3  NYC-Bronx Community District 11--Pelham Parkwa...  24830  449
# 4  NYC-Bronx Community District 3 & 6--Belmont, N...  18654  282

# %%
def converter_1(data):
    if re.search(r"Bronx", data, re.IGNORECASE):
        return re.sub(r"(\d\d)\s.+", r"BX\1", data)
    elif re.search(r"Queen", data, re.IGNORECASE):
        return re.sub(r"(\d\d)\s.+", r"QN\1", data)
    elif re.search(r"STATEN ISLAND", data, re.IGNORECASE):
        return re.sub(r"(\d\d)\s.+", r"SI\1", data)
    elif re.search(r"BROOKLYN", data, re.IGNORECASE):
        return re.sub(r"(\d\d)\s.+", r"BK\1", data)
    elif re.search(r"manhattan", data, re.IGNORECASE):
        return re.sub(r"(\d\d)\s.+", r"MN\1", data)

# %%
pat1 = re.compile(r"\w+-\w+\s*\w*\s\w+\s\w+\s(\d\d)\s*&*\d*.*", re.IGNORECASE)
pat2 = re.compile(r"\w+-\w+\s*\w*\s\w+\s\w+\s(\d)\s*&*\d*.*", re.IGNORECASE)

# %%
def converter_2(data):
    if re.search(r"Bronx", data,re.IGNORECASE):
        if re.search(pat1, data):
            return re.sub(pat1, r"BX\1", data)
        else:
            return re.sub(pat2, r"BX0\1", data)
    elif re.search(r"Queen", data,re.IGNORECASE):
         if re.search(pat1, data):
            return re.sub(pat1, r"QN\1", data)
         else:
            return re.sub(pat2, r"QN0\1", data)
    elif re.search(r"STATEN ISLAND", data, re.IGNORECASE):
         if re.search(pat1, data, ):
            return re.sub(pat1, r"SI\1", data)
         else:
            return re.sub(pat2, r"SI0\1", data)
    elif re.search(r"BROOKLYN", data, re.IGNORECASE):
         if re.search(pat1, data):
            return re.sub(pat1, r"BK\1", data)
         else:
            return re.sub(pat2, r"BK0\1", data)
    elif re.search(r"manhattan", data, re.IGNORECASE):
         if re.search(pat1, data):
            return re.sub(pat1, r"MN\1", data)
         else:
            return re.sub(pat2, r"MN0\1", data)

# %%
demo = demograph.drop_duplicates(subset="Median household income (In 2014 Inflation Adjusted Dollars)")

# %%
demo = demo.rename(columns = {'cd_id':'district'})

# %%
demo["district"][demo["district"]=="MN05"] = "MN04"
# Out:
# /opt/rh/anaconda/root/envs/PUI2016_Python3/lib/python3.5/site-packages/ipykernel/__main__.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   if __name__ == '__main__':

# %%
first = mobile_info.merge(it_info, on="Qualifying Name")

# %%
first["district"] = first["Qualifying Name"].apply(converter_2)

# %%
first.drop(["Qualifying Name"], axis=1, inplace=1)

# %%
first.drop_duplicates(inplace=1)

# %%
ranking["district"] = ranking["Community Board"].apply(converter_1)

# %%
ranking.drop(["Community Board"], axis=1, inplace=1)

# %%
ranking = ranking.drop_duplicates(subset="counts")

# %%
final = demo.merge(first, on="district", how="inner").merge(ranking, on="district", how="inner")

# %%
final
# Out:
#    district  Median household income (In 2014 Inflation Adjusted Dollars)  \
# 0      BX08                                              54224
# 1      BX12                                              44906
# 2      BX10                                              54962
# 3      BX11                                              47910
# 4      BX03                                              22041
# 5      BX07                                              35495
# 6      BX05                                              20872
# 7      BX04                                              27203
# 8      BX09                                              36058
# 9      BX01                                              21116
# 10     MN12                                              45157
# 11     MN09                                              42235
# 12     MN10                                              40564
# 13     MN11                                              31340
# 14     MN08                                             115238
# 15     MN07                                             106181
